# %% [markdown]
# ## Altmap Experiments
# ### Compare altmap to map eq using networkx

# %%
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.ticker import (AutoMinorLocator)
import numpy as np

# show plots in separate window
# %pylab
# load helpers and wrappers
# %run helpers.py
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
clique_size = 500
G = nx.complete_graph(clique_size)
G = nx.convert_node_labels_to_integers(G, first_label=1)

# ground truth
nodes_ids = list(range(1, clique_size+1))
labels = [1] * clique_size
communities = dict(zip(nodes_ids, labels))

cost = altmap_cost(G, communities)
print (f'Ground Truth each node L = {cost}')
# Out:
# Ground Truth each node L = 0.0

# %%
# run community detection
# communities_found, num_communities_found,_,_ = infomap(G, altmap=False)
# communities_found, num_communities_found,_,_ = infomap(G, altmap=True)
communities_found, num_communities_found,_,_ = infomap(G, altmap=True, init='sc')

# print results
print (communities_found)
print (f'We found {num_communities_found} communities.')

# cost = altmap_cost(G, communities_found)
# print (f'Achieved cost L = {cost}')
# Out:
# Spectral clustering finished in 0.2401270000000002 seconds.
# OrderedDict([(1, 2), (2, 3), (3, 4), (4, 1), (5, 5), (6, 6), (7, 7), (8, 8), (9, 9), (10, 10), (11, 11), (12, 12), (13, 13), (14, 14), (15, 15), (16, 16), (17, 17), (18, 18), (19, 19), (20, 20), (21, 21), (22, 22), (23, 23), (24, 24), (25, 25), (26, 26), (27, 27), (28, 28), (29, 29), (30, 30), (31, 31), (32, 1), (33, 32), (34, 33), (35, 34), (36, 1), (37, 35), (38, 36), (39, 37), (40, 38), (41, 39), (42, 40), (43, 41), (44, 42), (45, 43), (46, 44), (47, 45), (48, 46), (49, 1), (50, 47), (51, 48), (52, 49), (53, 50), (54, 51), (55, 52), (56, 53), (57, 54), (58, 55), (59, 56), (60, 57), (61, 58), (62, 59), (63, 60), (64, 61), (65, 1), (66, 62), (67, 63), (68, 64), (69, 65), (70, 66), (71, 67), (72, 68), (73, 69), (74, 70), (75, 71), (76, 72), (77, 73), (78, 74), (79, 75), (80, 76), (81, 77), (82, 78), (83, 79), (84, 80), (85, 81), (86, 82), (87, 83), (88, 84), (89, 85), (90, 86), (91, 87), (92, 88), (93, 89), (94, 90), (95, 91), (96, 92), (97, 93), (98, 94), (99, 95), (100, 96), (101, 97), (102, 98), (103, 99), (104, 100), (105, 101), (106, 102), (107, 103), (108, 104), (109, 105), (110, 106), (111, 107), (112, 108), (113, 109), (114, 1), (115, 110), (116, 111), (117, 112), (118, 113), (119, 114), (120, 115), (121, 116), (122, 117), (123, 118), (124, 119), (125, 120), (126, 121), (127, 122), (128, 123), (129, 124), (130, 125), (131, 126), (132, 127), (133, 128), (134, 129), (135, 130), (136, 131), (137, 132